# %% [markdown]
# # CHAPTER 1

# %% [markdown]
# ## 00.00 Preface

# %%
# Instalación de paquetes necesarios durante el curso
#%pip install numpy pandas scikit-learn matplotlib seaborn jupyter
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 11.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/11.0 MB 13.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.8/11.0 MB 14.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.0 MB 17.4 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.0 MB 20.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.6/11.0 MB 25.0 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 38.5 MB/s eta 0:00:01
# ...

# %% [markdown]
# ## 01.00 Preface IPython Beyond Normal

# %% [markdown]
# Ejecutar jupyter notebook desde la terminal
#
# $ jupyter notebook

# %% [markdown]
# ## 01.01 Help and Documentation

# %%
# Pedir ayuda de la función "len"
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
# Otra manera de pedir ayuda de una función es con "?"
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
# También funciona para métodos de objetos
L = [1, 2, 3]
L.insert?
# Out:
# Signature: L.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
# O en los objetos mismos
L?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
# También funciona para funciones propias
def square(a):
    """Return the square of a."""
    return a ** 2

square?
# Out:
# Signature: square(a)
# Docstring: Return the square of a.
# File:      c:\users\asus\appdata\local\temp\ipykernel_12852\1755828323.py
# Type:      function

# %%
# Acceder al código fuente con "??"
square??
# Out:
# Signature: square(a)
# Source:
# def square(a):
#     """Return the square of a."""
#     return a ** 2
# File:      c:\users\asus\appdata\local\temp\ipykernel_12852\1755828323.py
# Type:      function

# %%
# En alguinos casos, "??" no da el código fuente, sino la misma respuesta que con "?"
len??
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %% [markdown]
# ### Completado de contenido con tabulaciones (TAB)
# *L.(TAB)*
#
# L.append   L.copy     L.extend   L.insert   L.remove   L.sort     L.clear    L.count    L.index    L.pop      L.reverse
#
# **Escribir los primeros caracteres reduce las opciones**
#
# *L.c(TAB)*  //   L.clear  L.copy   L.count
#
# *L.co(TAB)* //    L.copy   L.count
#
# **Si solo hay una opción, utilizar (TAB) completara la linea**
#
# *L.cou(TAB)* --> L.count
#
# **(Tab) es util al importar objetos desde paquetes. Aqui podemos ver todos los disponibles del paquete *itertools* que comienzan con *co*:
#
# *from itertools import co(TAB)*   combinations / compress / combinations_with_replacement / count
#
# **De manera simila, se pueden ver que importaciones están disponibles en tu sistema.
#
# *import (TAB)*
#
# Display all 399 possibilities? (y or n)
#
# Crypto /             dis /                py_compile /
# Cython /             distutils /          pyclbr /
# ... /
# difflib /            pwd /                zmq

# %% [markdown]
# **(TAB) es útil si se conocen los primeros caracteres, pero también sería útil poder buscar por caracteres en medio o al final de la palabra. Para ello, también se pueden realizar busquedas por patrones (wildcard matching) con * . Por ejemplo, buscar todo lo que termine con *Warning* :**

# %%
*Warning?
# Out:
# BytesWarning
# DeprecationWarning
# EncodingWarning
# FutureWarning
# ImportWarning
# PendingDeprecationWarning
# ResourceWarning
# RuntimeWarning
# SyntaxWarning
# UnicodeWarning
# UserWarning
# Warning

# %%
# De manera similar, podemos buscar métodos que contengan la palabra 'find' en alguna parte
str.*find*?
# Out:
# str.find
# str.rfind

# %% [markdown]
# ## 01.02 Shell Keyboard Shortcuts (IPython)

# %% [markdown]
# ### Atajos
#
# #### Navegación
#
# | Tecla | Acción |
# |:--------:|:--------:|
# | Ctrl-a | Mueve el cursor al inicio de la linea |
# | Ctrl-e | Mueve el cursor al final de la linea |
# | Ctrl-b (o flecha izquierda) | Mueve el cursor un caracter hacia atrás |
# | Ctrl-f (o flecha derecha)| Mueve el cursor un caracter hacia adelante |
#
# #### Entrada de texto
#
# | Tecla | Acción |
# |:--------:|:--------:|
# | Retroceso | Borra el caracter anterior |
# | Ctrl-d | Borra el siguiente caracter |
# | Ctrl-k | Corta texto desde el cursor hasta el final |
# | Ctrl-u | Corta texto desde el inicio hasta el cursor |
# | Ctrl-y | Pegar texto que fue cortado previamente |
# | Ctrl-t | Transponer (cambiar) los dos caracteres anteriores |
#
# #### Historial de comandos
#
# | Tecla | Acción |
# |:--------:|:--------:|
# | Ctrl-p (o flecha arriba) | Accede al comando anterior |
# | Ctrl-n (o flecha abajo) | Accede al comando siguiente |
# | Ctrl-r | Búsqueda inversa en el historial de comandos |
#
# **Uso de *Búsqueda inversa (Ctrl-r)***
#
# *(Ctrl-r) 'sqa'*: -> square??
#
# **Si se pulsa *(Ctrl-r)* de nuevo, busca el siguiente comando que coincida.**
#
# *(Ctrl-r) 'sqa'*: -> def square(a):
#
# **Cuando se ha encontrado el comando deseado, con Enter la búsqueda terminará para utilizar el comando recuperado.**
#
# *def square(a):
#     """Return the square of a"""
#     return a ** 2*
#
# **Los comandos *(Ctrl-p)/(Ctrl-n)* se pueden usar de manera similar, pero solo haciendo coincidir los caracteres al principio de la línea**
#
# | Tecla | Acción |
# |:--------:|:--------:|
# | Ctrl-l | Limpia la pantalla de terminal |
# | Ctrl-c | Interrumpe el comando actual de Python |
# | Ctrl-d | Sale de la sesión de IPython |

# %% [markdown]
# ## 01.03 Magic Commands

# %% [markdown]
# El pegado directo de un código externo "tal cual" normalmente daría error, como el siguiente:
#
# '>>> def donothing(x):
# <br>...     return x
#
# Esto es así ya que el interpretador no reconoce los caracteres de promot (>>>) como tal.
#
# Sin embargo, la función *%paste* de IPython (y nativamente implementado en Jupyter) está diseñado para manejar esto:
#
# **En IPython**
#  %paste
# <br> '>>> def donothing(x):
# <br>  ...     return x

# %%
# En Jupyter
>>> def donothing(x):
...     return x

# %% [markdown]
# *%paste* ejecuta directamente el código, pero el comando *%cpaste* habre un prompt interactivo multilinea
# <br> %cpaste
# <br> Pasting code; enter '--' alone on the line to stop or use Ctrl-D.
# <br> :>>> def donothing(x):
# <br> :...     return x
# <br> :--

# %% [markdown]
# Algunos otros códigos útiles en IPython son:
# <br> ***%run*** Permite correr código en una nueva ventana, en lugar de utilizar la ventana principal. Esto es útil cuando se quieren probar funciones, o si se tiene un documento de texto con código que deseamos reutilizar y probar primero antes de integrarlo en el código principal.

# %%
# Por ejemplo, si se tiene un archibo *myscript.py* con el código siguiente: <br>
def square(x):
    """square a number"""
    return x ** 2

for N in range(1, 4):
    print(N, "squared is", square(N))
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9

# %% [markdown]
# Puede ser ejecutar desde IPython de la siguiente manera:
# <br> %run myscript.py
# <br> 1 squared is 1
# <br> 2 squared is 4
# <br> 3 squared is 9

# %% [markdown]
# ***%timeit*** devuelve el tiempo de ejecución de una linea de código, particularmente para evaluar el rendimiento.

# %%
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 91.5 µs ± 4.1 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ***%%timeit*** es unaversión multilineas

# %%
# %%timeit
   ...: L = []
   ...: for n in range(1000):
   ...:     L.append(n ** 2)
   ...:
# Out:
# 104 µs ± 7.01 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# Se puede obtener m información de las funciones "mágicas" de IPython también con *?*.
# %timeit?
# Out:
# Docstring:
# Time execution of a Python statement or expression
#
# Usage, in line mode:
#   %timeit [-n<N> -r<R> [-t|-c] -q -p<P> -o] statement
# or in cell mode:
#   %%timeit [-n<N> -r<R> [-t|-c] -q -p<P> -o] setup_code
#   code
#   code...
#
# Time execution of a Python statement or expression using the timeit
# module.  This function can be used both as a line and cell magic:
#
# - In line mode you can time a single-line statement (though multiple
#   ones can be chained with using semicolons).
#
# - In cell mode, the statement in the first line is used as setup code
#   (executed but not timed) and the body of the cell is timed.  The cell
#   body has access to any variables created in the setup code.
#
# Options:
# -n<N>: execute the given statement <N> times in a loop. If <N> is not
# provided, <N> is determined so as to get sufficient accuracy.
#
# -r<R>: number of repeats <R>, each consisting of <N> loops, and take the
# average result.
# Default: 7
#
# ...

# %%
# O acceder a la documentación con %magic
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %%
# U obtener una lista de todas las funciones mágicas
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# ## 01.04 Input-Output History

# %%
import math

# %%
math.sin(2)
# Out:
# 0.9092974268256817

# %%
math.cos(2)
# Out:
# -0.4161468365471424

# %%
print(In[17:21])
# Out:
# ['import math', 'math.sin(2)', 'math.cos(2)', 'print(In[17:21])']

# %%
Out
# Out:
# {16: Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
print(In[17])
# Out:
# import math

# %%
Out[18] ** 2 + Out[19] ** 2
# Out:
# 1.0

# %%
print(_)
print(__)
print(___)
# Out:
# 1.0
# -0.4161468365471424
# 0.9092974268256817

# %%
Out[18]
# Out:
# 0.9092974268256817

# %%
_18
# Out:
# 0.9092974268256817

# %%
math.sin(2) + math.cos(2);

# %%
27 in Out
# Out:
# False

# %%
# %history -n 17-20
# Out:
#   17: import math
#   18: math.sin(2)
#   19: math.cos(2)
#   20: print(In[17:21])

# %% [markdown]
# ## 01.05 IPython and Shell Commands

# %%
ls
# Out:
#  El volumen de la unidad G es jhordan.ojeda@uabc.edu.mx - G...
#  El n£mero de serie del volumen es: 1983-1116
#
#  Directorio de G:\Mi unidad\CICESE\5. Doctorado\4. Cursos\1. Introducci¢n a la Ciencia de Datos\3. icd2024\1. Book
#
# 27/10/2024  05:12 p. m.    <DIR>          .
# 22/10/2024  09:03 p. m.    <DIR>          ..
# 27/10/2024  05:12 p. m.    <DIR>          .ipynb_checkpoints
# 27/10/2024  05:12 p. m.           195,165 1.ipynb
#                1 archivos        195,165 bytes
#                3 dirs  14,856,269,824 bytes libres

# %%
pwd
# Out:
# 'G:\\Mi unidad\\CICESE\\5. Doctorado\\4. Cursos\\1. Introducción a la Ciencia de Datos\\3. icd2024\\1. Book'

# %%
echo "printing from the shell
# Out:
# "printing from the shell

# %%
contents = !ls
print(contents)
# Out:
# ['"ls" no se reconoce como un comando interno o externo,', 'programa o archivo por lotes ejecutable.']

# %%
directory = !pwd
print(directory)
# Out:
# ['"pwd" no se reconoce como un comando interno o externo,', 'programa o archivo por lotes ejecutable.']

# %%
type(directory)
# Out:
# IPython.utils.text.SList

# %%
message = "hello from Python"

# %%
echo {message}
# Out:
# hello from Python

# %%
pwd
# Out:
# 'G:\\Mi unidad\\CICESE\\5. Doctorado\\4. Cursos\\1. Introducción a la Ciencia de Datos\\3. icd2024\\1. Book'

# %%
cd ..
# Out:
# G:\Mi unidad\CICESE\5. Doctorado\4. Cursos\1. Introducción a la Ciencia de Datos\3. icd2024

# %%
pwd
# Out:
# 'G:\\Mi unidad\\CICESE\\5. Doctorado\\4. Cursos\\1. Introducción a la Ciencia de Datos\\3. icd2024'

# %%
# %cd ..
# Out:
# G:\Mi unidad\CICESE\5. Doctorado\4. Cursos\1. Introducción a la Ciencia de Datos

# %%
cd "3. icd2024\\1. Book"
# Out:
# G:\Mi unidad\CICESE\5. Doctorado\4. Cursos\1. Introducción a la Ciencia de Datos\3. icd2024\1. Book
# C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
mkdir tmp

# %%
ls
# Out:
#  El volumen de la unidad G es jhordan.ojeda@uabc.edu.mx - G...
#  El n£mero de serie del volumen es: 1983-1116
#
#  Directorio de G:\Mi unidad\CICESE\5. Doctorado\4. Cursos\1. Introducci¢n a la Ciencia de Datos\3. icd2024\1. Book
#
# 27/10/2024  05:22 p. m.    <DIR>          .
# 22/10/2024  09:03 p. m.    <DIR>          ..
# 27/10/2024  05:12 p. m.    <DIR>          .ipynb_checkpoints
# 27/10/2024  05:20 p. m.           201,193 1.ipynb
# 27/10/2024  05:22 p. m.    <DIR>          tmp
#                1 archivos        201,193 bytes
#                4 dirs  14,863,183,872 bytes libres

# %% [markdown]
# ## 01.06 Errores and Debugging

# %%
def func1(a, b):
    return a / b

def func2(x):
    a = x
    b = x - 1
    return func1(a, b)

# %%
func2(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 func2(1)
#
# Cell In[93], line 7, in func2(x)
#       5 a = x
#       6 b = x - 1
# ----> 7 return func1(a, b)
#
# Cell In[93], line 2, in func1(a, b)
#       1 def func1(a, b):
# ----> 2     return a / b
#
# ZeroDivisionError: division by zero

# %%
# %xmode Plain
# Out:
# Exception reporting mode: Plain

# %%
func2(1)
# Out:
# Traceback (most recent call last):
#
#   Cell In[96], line 1
#     func2(1)
#
#   Cell In[93], line 7 in func2
#     return func1(a, b)
#
#   Cell In[93], line 2 in func1
#     return a / b
#
# ZeroDivisionError: division by zero

# %%
# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
func2(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 func2(1)
#
# Cell In[93], line 7, in func2(x=1)
#       5 a = x
#       6 b = x - 1
# ----> 7 return func1(a, b)
#         a = 1
#         b = 0
#
# Cell In[93], line 2, in func1(a=1, b=0)
#       1 def func1(a, b):
# ----> 2     return a / b
#         a = 1
#         b = 0
#
# ZeroDivisionError: division by zero

# %%
# %debug
# Out:
# > c:\users\asus\appdata\local\temp\ipykernel_12852\4021589855.py(2)func1()
# ipdb>  a
# a = 1
# b = 0
# ipdb>  b
# ipdb>  quit

# %%
# %debug
# Out:
# > c:\users\asus\appdata\local\temp\ipykernel_12852\4021589855.py(2)func1()
# ipdb>  up
# > c:\users\asus\appdata\local\temp\ipykernel_12852\4021589855.py(7)func2()
# ipdb>  print(x)
# 1
# ipdb>  up
# > c:\users\asus\appdata\local\temp\ipykernel_12852\2483606204.py(1)<module>()
# ipdb>  down
# > c:\users\asus\appdata\local\temp\ipykernel_12852\4021589855.py(7)func2()
# ipdb>  quit

# %%
# %xmode Plain
# %pdb on
func2(1)
# Out:
# Exception reporting mode: Plain
# Automatic pdb calling has been turned ON
# Traceback (most recent call last):
#
#   Cell In[101], line 3
#     func2(1)
#
#   Cell In[93], line 7 in func2
#     return func1(a, b)
#
#   Cell In[93], line 2 in func1
#     return a / b
#
# ZeroDivisionError: division by zero
# > c:\users\asus\appdata\local\temp\ipykernel_12852\4021589855.py(2)func1()
# ipdb>  print(b)
# 0
# ipdb>  quit

# %% [markdown]
# | Command | Description |
# |:--------:|:--------:|
# | list | Show the current location in the file |
# | help | Show a list of commands, or find help on a specific command |
# | q(uit) | Quit the debugger and the program |
# | c(ontinue) | Quit the debugger, continue in the program |
# | n(ext) | Go to the next step of the program |
# | <enter'> | Repeat the previous command |
# | p(rint) | Print variables |
# | s(tep) | Step into a subroutine |
# | r(eturn) | Return out of a subroutine |

# %% [markdown]
# ## 01.07 Timing and Profiling

# %%
# %timeit sum(range(100))
# Out:
# 925 ns ± 88.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# 202 ms ± 12.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import random
L = [random.random() for i in range(100000)]
# %timeit L.sort()
# Out:
# 1.02 ms ± 60.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import random
L = [random.random() for i in range(100000)]
print("sorting an unsorted list:")
# %time L.sort()
# Out:
# sorting an unsorted list:
# CPU times: total: 15.6 ms
# Wall time: 24 ms

# %%
print("sorting an already sorted list:")
# %time L.sort()
# Out:
# sorting an already sorted list:
# CPU times: total: 0 ns
# Wall time: 4 ms

# %%
# %%time
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# CPU times: total: 391 ms
# Wall time: 386 ms

# %%
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
    return total

# %%
# %prun sum_of_lists(1000000)
# Out:
#          455 function calls (446 primitive calls) in 1.138 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.874    0.874    1.038    1.038 3519952779.py:1(sum_of_lists)
#         5    0.164    0.033    0.164    0.033 {built-in method builtins.sum}
#        13    0.055    0.004    0.055    0.004 socket.py:626(send)
#         1    0.024    0.024    0.055    0.055 iostream.py:276(<lambda>)
#         1    0.017    0.017    1.054    1.054 <string>:1(<module>)
#         1    0.002    0.002    0.002    0.002 selector_events.py:141(_write_to_self)
#         1    0.001    0.001    0.002    0.002 _base.py:537(set_result)
#         2    0.001    0.000    0.004    0.002 {method 'run' of '_contextvars.Context' objects}
#         1    0.001    0.001    0.001    0.001 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# ...

# %%
#pip install line_profiler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext line_profiler

# %%
# %lprun -f sum_of_lists sum_of_lists(5000)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0139729 s
# File: C:\Users\Asus\AppData\Local\Temp\ipykernel_12852\3519952779.py
# Function: sum_of_lists at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      1                                           def sum_of_lists(N):
#      2         1         10.0     10.0      0.0      total = 0
#      3         6         74.0     12.3      0.1      for i in range(5):
#      4     25005     137912.0      5.5     98.7          L = [j ^ (j >> i) for j in range(N)]
#      5         5       1724.0    344.8      1.2          total += sum(L)
#      6         1          9.0      9.0      0.0      return total

# %%
#pip install memory_profiler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext memory_profiler

# %%
# %memit sum_of_lists(1000000)
# Out:
# peak memory: 162.08 MiB, increment: 73.70 MiB

# %%
# %%file mprun_demo.py
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
        del L # remove reference to L
    return total
# Out:
# Writing mprun_demo.py

# %%
from mprun_demo import sum_of_lists
# %mprun -f sum_of_lists sum_of_lists(1000000)
# Out:
# Filename: G:\Mi unidad\CICESE\5. Doctorado\4. Cursos\1. Introducción a la Ciencia de Datos\3. icd2024\1. Book\mprun_demo.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# ...
#      1     88.4 MiB     88.4 MiB           1   def sum_of_lists(N):
#      2     88.4 MiB      0.0 MiB           1       total = 0
#      3     91.2 MiB      0.0 MiB           6       for i in range(5):
#      4    123.9 MiB -57108525.1 MiB     5000005           L = [j ^ (j >> i) for j in range(N)]
#      5    123.9 MiB     -0.0 MiB           5           total += sum(L)
#      6     91.2 MiB   -139.3 MiB           5           del L # remove reference to L
#      7     91.2 MiB      0.0 MiB           1       return total
